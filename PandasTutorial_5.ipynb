# %% [markdown]
# ## (Part 5)
# https://www.youtube.com/watch?v=DCDe29sIKcE

# %%
import pandas as pd

# %%
people = {
    "first": ["Joshua","Rebecca","Diane","John"],
    "middle": ["Daniel", "Lee", "Elizabeth", "Kohler"],
    "last": ["Harvey", "Winter", "McCabe", "Marsh"],
    "age": [31,27,60,58],
    "gender": ["m","female","female","m"]
}

# %%
peeps = pd.DataFrame(people)

# %%
peeps
# Out:
#      first     middle    last  age  gender
# 0   Joshua     Daniel  Harvey   31       m
# 1  Rebecca        Lee  Winter   27  female
# 2    Diane  Elizabeth  McCabe   60  female
# 3     John     Kohler   Marsh   58       m

# %% [markdown]
# ### Modifying Column Headers

# %%
peeps.columns
# Out:
# Index(['first', 'middle', 'last', 'age', 'gender'], dtype='object')

# %%
peeps.columns = ['first name','middle name','last name','age','gender']

# %%
peeps.columns = [x.upper() for x in peeps.columns]

# %%
peeps
# Out:
#   FIRST NAME MIDDLE NAME LAST NAME  AGE  GENDER
# 0     Joshua      Daniel    Harvey   31       m
# 1    Rebecca         Lee    Winter   27  female
# 2      Diane   Elizabeth    McCabe   60  female
# 3       John      Kohler     Marsh   58       m

# %%
peeps.columns = peeps.columns.str.replace(' ','_')

# %%
peeps
# Out:
#   FIRST_NAME MIDDLE_NAME LAST_NAME  AGE  GENDER
# 0     Joshua      Daniel    Harvey   31       m
# 1    Rebecca         Lee    Winter   27  female
# 2      Diane   Elizabeth    McCabe   60  female
# 3       John      Kohler     Marsh   58       m

# %%
new_col_names = {'FIRST_NAME':'FIRST','MIDDLE_NAME':'MIDDLE','LAST_NAME':'LAST'}
peeps.rename(columns=new_col_names,inplace=True)

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER
# 0   Joshua     Daniel  Harvey   31       m
# 1  Rebecca        Lee  Winter   27  female
# 2    Diane  Elizabeth  McCabe   60  female
# 3     John     Kohler   Marsh   58       m

# %% [markdown]
# ### Modifying Rows

# %%
peeps.loc[2]
# Out:
# FIRST         Diane
# MIDDLE    Elizabeth
# LAST         McCabe
# AGE              60
# GENDER       female
# Name: 2, dtype: object

# %%
peeps.loc[2] = ['Dianne', 'Eliz', 'McC', 60,'female']

# %%
peeps
# Out:
#      FIRST  MIDDLE    LAST  AGE  GENDER
# 0   Joshua  Daniel  Harvey   31       m
# 1  Rebecca     Lee  Winter   27  female
# 2   Dianne    Eliz     McC   60  female
# 3     John  Kohler   Marsh   58       m

# %%
peeps.loc[2,['FIRST','MIDDLE', 'LAST']] = ['Diane', 'Elizabeth', 'McCabe']

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER
# 0   Joshua     Daniel  Harvey   31       m
# 1  Rebecca        Lee  Winter   27  female
# 2    Diane  Elizabeth  McCabe   60  female
# 3     John     Kohler   Marsh   58       m

# %%
# -- change only a single column and single row (cell)
peeps.loc[3,'MIDDLE'] = 'K'

# %%
# filt_gen = peeps['GENDER'] == 'male'
filt_gen = peeps['GENDER'].str.contains('tant')
peeps.loc[filt_gen, 'GENDER'] = 'male'
peeps['GENDER'] = peeps['GENDER'].str.upper()

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER
# 0   Joshua     Daniel  Harvey   31       M
# 1  Rebecca        Lee  Winter   27  FEMALE
# 2    Diane  Elizabeth  McCabe   60  FEMALE
# 3     John          K   Marsh   58       M

# %% [markdown]
# ### apply, map, applymap, replace

# %%
peeps['GENDER'].apply(len)
# Out:
# 0    1
# 1    6
# 2    6
# 3    1
# Name: GENDER, dtype: int64

# %%
def update_email(middle):
    return middle.upper()

# %%
peeps['MIDDLE'] = peeps['MIDDLE'].apply(update_email)

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER
# 0   Joshua     DANIEL  Harvey   31       M
# 1  Rebecca        LEE  Winter   27  FEMALE
# 2    Diane  ELIZABETH  McCabe   60  FEMALE
# 3     John          K   Marsh   58       M

# %%
peeps['MIDDLE'] = peeps['MIDDLE'].apply(lambda x: x.lower())

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER
# 0   Joshua     daniel  Harvey   31       M
# 1  Rebecca        lee  Winter   27  FEMALE
# 2    Diane  elizabeth  McCabe   60  FEMALE
# 3     John          k   Marsh   58       M

# %%
# -- list of columns can not be modified in this way
# peeps[['FIRST','MIDDLE']] = peeps[['FIRST','MIDDLE']].apply(lambda x: x.upper())

# %%
# -- apply used on the dataframe not the series
# --  counts of values in each column
peeps.apply(len)
# Out:
# FIRST     4
# MIDDLE    4
# LAST      4
# AGE       4
# GENDER    4
# dtype: int64

# %%
# -- counts the values in each row 
peeps.apply(len, axis='columns')
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
peeps.apply(pd.Series.min)
# Out:
# FIRST      Diane
# MIDDLE    daniel
# LAST      Harvey
# AGE           27
# GENDER    FEMALE
# dtype: object

# %%
# -- use of applymap to get values on entire vector object
peeps[['FIRST','MIDDLE','LAST','GENDER']].applymap(len)
# Out:
#    FIRST  MIDDLE  LAST  GENDER
# 0      6       6     6       1
# 1      7       3     6       6
# 2      5       9     6       6
# 3      4       1     5       1

# %%
# -- destructively substitutes values and non declared subs get assigned as 'NaN'
peeps['GENDER'].map({'FEMALE':'F','MALE':'M'})
# Out:
# 0    NaN
# 1      F
# 2      F
# 3    NaN
# Name: GENDER, dtype: object

# %%
peeps['GENDER'].replace({'FEMALE':'Fem','MALE':'Mal'})
# Out:
# 0      M
# 1    Fem
# 2    Fem
# 3      M
# Name: GENDER, dtype: object

# %% [markdown]
# ### switching back to stackoverflow data sets

# %%
import os
os.chdir('./data')
os.getcwd()
# Out:
# 'C:\\Users\\Joshua\\Desktop\\PERSONAL\\Joshua Harvey\\education\\youtube\\Corey Schafer\\Python Tutorials\\data'

# %%
path = os.path.join(os.getcwd(),'..\data\survey_results_public.csv')
path
# Out:
# 'C:\\Users\\Joshua\\Desktop\\PERSONAL\\Joshua Harvey\\education\\youtube\\Corey Schafer\\Python Tutorials\\data\\..\\data\\survey_results_public.csv'

# %%
df = pd.read_csv(path)

# %%
pd.set_option('display.max_rows',85)
pd.set_option('display.max_columns',25)

# %%
df_cols = pd.DataFrame(df.columns)
df_cols.columns = ['title']
df_cols.sort_values(by=['title'])
# Out:
#                      title
# 77                     Age
# 14              Age1stCode
# 58              BetterLife
# 57            BlockchainIs
# 56           BlockchainOrg
# 16               CareerSat
# 38                 CodeRev
# 39              CodeRevHrs
# 30                CompFreq
# 29               CompTotal
# 55              Containers
# 31           ConvertedComp
# 6                  Country
# 28            CurrencyDesc
# 27          CurrencySymbol
# 46  DatabaseDesireNextYear
# 45      DatabaseWorkedWith
# 82              Dependents
# 53              DevEnviron
# 12                 DevType
# 8                  EdLevel
# 10                EduOther
# 5               Employment
# 73                EntTeams
# 81               Ethnicity
# 62            Extraversion
# 24                FizzBuzz
# 78                  Gender
# 2                 Hobbyist
# 59                ITperson
# 37                  ImpSyn
# 25              JobFactors
# 17                  JobSat
# 21                 JobSeek
# 44  LanguageDesireNextYear
# 43      LanguageWorkedWith
# 22            LastHireDate
# 23                 LastInt
# 1               MainBranch
# 18                MgrIdiot
# 19                MgrMoney
# 20                 MgrWant
# 52  MiscTechDesireNextYear
# 51      MiscTechWorkedWith
# 60                   OffOn
# 54                   OpSys
# 4               OpenSource
# 3              OpenSourcer
# 11                 OrgSize
# 48  PlatformDesireNextYear
# 47      PlatformWorkedWith
# 41             PurchaseHow
# 42            PurchaseWhat
# 0               Respondent
# 26            ResumeUpdate
# 70               SOAccount
# 74                  SOComm
# 67            SOFindAnswer
# 69           SOHowMuchTime
# 72                  SOJobs
# 76            SONewContent
# 71              SOPartFreq
# 68             SOTimeSaved
# 64              SOVisit1st
# 65             SOVisitFreq
# 66               SOVisitTo
# 63              ScreenName
# 80               Sexuality
# 61             SocialMedia
# 7                  Student
# 84              SurveyEase
# 83            SurveyLength
# 79                   Trans
# 9           UndergradMajor
# 40               UnitTests
# 50  WebFrameDesireNextYear
# 49      WebFrameWorkedWith
# 75           WelcomeChange
# 34           WorkChallenge
# 36                 WorkLoc
# 33                WorkPlan
# 35              WorkRemote
# 32             WorkWeekHrs
# 13               YearsCode
# 15            YearsCodePro

# %%
df.rename(columns={'ConvertedComp':'Newy'},inplace=True)

# %%
set(df['OpenSourcer'])
# Out:
# {'Less than once a month but more than once per year',
#  'Less than once per year',
#  'Never',
#  'Once a month or more often'}

# %%
df['OpenSourcer'].replace({'Less than once a month but more than once per year': 'Seldom','Less than once per year': 'Hardly', 'Never':'Slacker','Once a month or more often':'Frequent'}, inplace=True)

# %%
df.loc[0:4,'Respondent':'OpenSource']
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#   OpenSourcer                                         OpenSource
# 0     Slacker  The quality of OSS and closed source software ...
# 1      Hardly  The quality of OSS and closed source software ...
# 2     Slacker  The quality of OSS and closed source software ...
# 3     Slacker  The quality of OSS and closed source software ...
# 4    Frequent  OSS is, on average, of HIGHER quality than pro...

# %% [markdown]
# ## (Part 6)

# %% [markdown]
# ### adding columns

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER
# 0   Joshua     daniel  Harvey   31       M
# 1  Rebecca        lee  Winter   27  FEMALE
# 2    Diane  elizabeth  McCabe   60  FEMALE
# 3     John          k   Marsh   58       M

# %%
peeps['FIRST']+' '+peeps['LAST']
# Out:
# 0     Joshua Harvey
# 1    Rebecca Winter
# 2      Diane McCabe
# 3        John Marsh
# dtype: object

# %%
peeps['full_name'] = peeps['FIRST']+' '+peeps['LAST']
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER       full_name
# 0   Joshua     daniel  Harvey   31       M   Joshua Harvey
# 1  Rebecca        lee  Winter   27  FEMALE  Rebecca Winter
# 2    Diane  elizabeth  McCabe   60  FEMALE    Diane McCabe
# 3     John          k   Marsh   58       M      John Marsh

# %%
peeps.drop(columns=['full_name', 'GENDER'])
# Out:
#      FIRST     MIDDLE    LAST  AGE
# 0   Joshua     daniel  Harvey   31
# 1  Rebecca        lee  Winter   27
# 2    Diane  elizabeth  McCabe   60
# 3     John          k   Marsh   58

# %%
peeps['full_name'] = peeps['full_name'].str.lower()

# %%
peeps['full_name'].str.split(' ', expand=True)
# Out:
#          0       1
# 0   joshua  harvey
# 1  rebecca  winter
# 2    diane  mccabe
# 3     john   marsh

# %%
peeps[['first_lower','last_lower']] = peeps['full_name'].str.split(' ', expand=True)

# %%
# -- adds 
peeps
# Out:
#      FIRST     MIDDLE    LAST  AGE  GENDER       full_name first_lower  \
# 0   Joshua     daniel  Harvey   31       M   joshua harvey      joshua
# 1  Rebecca        lee  Winter   27  FEMALE  rebecca winter     rebecca
# 2    Diane  elizabeth  McCabe   60  FEMALE    diane mccabe       diane
# 3     John          k   Marsh   58       M      john marsh        john
#
#   last_lower
# 0     harvey
# 1     winter
# 2     mccabe
# 3      marsh

# %%
peeps = peeps.append({'FIRST': 'Shawn', 'MIDDLE': 'Michael', 'LAST': 'Lupa', 'GENDER': 'M'}, ignore_index=True)

# %%
filt_shawn = peeps['FIRST'].str.contains('Shawn')

# %%
peeps.loc[4, ['FIRST','full_name']] = ['Shawn','shawn lupa']

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST   AGE  GENDER       full_name first_lower  \
# 0   Joshua     daniel  Harvey  31.0       M   joshua harvey      joshua
# 1  Rebecca        lee  Winter  27.0  FEMALE  rebecca winter     rebecca
# 2    Diane  elizabeth  McCabe  60.0  FEMALE    diane mccabe       diane
# 3     John          k   Marsh  58.0       M      john marsh        john
# 4    Shawn        NaN     NaN   NaN     NaN      shawn lupa         NaN
#
#   last_lower
# 0     harvey
# 1     winter
# 2     mccabe
# 3      marsh
# 4        NaN

# %%
people2 = {
    "first": ["James","Kelly"],
    "middle": ["Sawyer", "Jean"],
    "last": ["Lupa", "Richards"],
    "age": [8,45],
    "gender": ["male","female"]
}
peeps2 = pd.DataFrame(people2)
peeps2
# Out:
#    first  middle      last  age  gender
# 0  James  Sawyer      Lupa    8    male
# 1  Kelly    Jean  Richards   45  female

# %%
peeps = peeps.append(peeps2, ignore_index=True)

# %%
peeps
# Out:
#      FIRST     MIDDLE    LAST   AGE  GENDER       full_name first_lower  \
# 0   Joshua     daniel  Harvey  31.0       M   joshua harvey      joshua
# 1  Rebecca        lee  Winter  27.0  FEMALE  rebecca winter     rebecca
# 2    Diane  elizabeth  McCabe  60.0  FEMALE    diane mccabe       diane
# 3     John          k   Marsh  58.0       M      john marsh        john
# 4    Shawn        NaN     NaN   NaN     NaN      shawn lupa         NaN
# 5      NaN        NaN     NaN   NaN     NaN             NaN         NaN
# 6      NaN        NaN     NaN   NaN     NaN             NaN         NaN
#
#   last_lower  first  middle      last   age  gender
# 0     harvey    NaN     NaN       NaN   NaN     NaN
# 1     winter    NaN     NaN       NaN   NaN     NaN
# 2     mccabe    NaN     NaN       NaN   NaN     NaN
# 3      marsh    NaN     NaN       NaN   NaN     NaN
# 4        NaN    NaN     NaN       NaN   NaN     NaN
# 5        NaN  James  Sawyer      Lupa   8.0    male
# 6        NaN  Kelly    Jean  Richards  45.0  female

# %%
# -- str.contains doesn't work b/c it returns NaN values instead of False or True
peeps[peeps['first'].str.contains('Kelly')].index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-5bc07b366384> in <module>
# ----> 1 peeps[peeps.loc[:,'first'].str.contains('Kelly')].index
#
# c:\users\joshua\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
# -> 2790         if com.is_bool_indexer(key):
#    2791             return self._getitem_bool_array(key)
#    2792
#
# c:\users\joshua\appdata\local\programs\python\python38\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     134                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
peeps.drop(peeps[peeps['first'] == 'Kelly'].index)
# Out:
#      FIRST     MIDDLE    LAST   AGE  GENDER       full_name first_lower  \
# 0   Joshua     daniel  Harvey  31.0       M   joshua harvey      joshua
# 1  Rebecca        lee  Winter  27.0  FEMALE  rebecca winter     rebecca
# 2    Diane  elizabeth  McCabe  60.0  FEMALE    diane mccabe       diane
# 3     John          k   Marsh  58.0       M      john marsh        john
# 4    Shawn        NaN     NaN   NaN     NaN      shawn lupa         NaN
# 5      NaN        NaN     NaN   NaN     NaN             NaN         NaN
#
#   last_lower  first  middle  last  age gender
# 0     harvey    NaN     NaN   NaN  NaN    NaN
# 1     winter    NaN     NaN   NaN  NaN    NaN
# 2     mccabe    NaN     NaN   NaN  NaN    NaN
# 3      marsh    NaN     NaN   NaN  NaN    NaN
# 4        NaN    NaN     NaN   NaN  NaN    NaN
# 5        NaN  James  Sawyer  Lupa  8.0   male

# %%
peeps.index
# Out:
# RangeIndex(start=0, stop=7, step=1)
